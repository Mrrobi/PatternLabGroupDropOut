# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import KFold

# %%
pos_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_pos_ENAC.npy"
neg_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_neg_ENAC.npy"
pos_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_pos_ENAC.npy"
neg_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_neg_ENAC.npy"

x_train_pos = np.load(pos_5289) 
x_train_neg = np.load(neg_5289) 
x_test_pos = np.load(pos_1000) 
x_test_neg = np.load(neg_1000) 

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
print(x_test_neg.shape)
print(y_test_neg.shape)

print(x_train_neg.shape)
print(y_train_neg.shape)

# %%
print(x_test_pos)

# %%
seed = 40
np.random.seed(seed)

# %%
x_training = np.concatenate((x_train_pos, x_train_neg), axis= 0)
y_training = np.concatenate((y_train_pos, y_train_neg))

# %%
x_test = np.concatenate((x_test_pos, x_test_neg))
y_test = np.concatenate((y_test_pos, y_test_neg))

# %%
print(x_training)
# Out:
# [[0.   0.2  0.   ... 0.25 0.5  0.2 ]
#  [0.   0.   0.2  ... 0.75 0.   0.2 ]
#  [0.6  0.2  0.2  ... 0.   0.5  0.2 ]
#  ...
#  [0.4  0.   0.75 ... 0.2  0.   0.2 ]
#  [0.2  0.25 0.5  ... 0.   0.2  0.4 ]
#  [0.6  0.   0.5  ... 0.2  0.4  0.2 ]]

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (2000, 148)
# (2000,)

# %%
print(x_training.shape)
# Out:
# (10578, 148)

# %%
kf = KFold(n_splits=5, random_state=seed)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
listc=[.10,.20,.30,.45,.50,.65,.75,.80,.95,.90]
for j in listc:
  c=j
  clf = SVC(C=c,  random_state = seed)
  val_accuracy_list = []
  train_accuracy_list = []
  sum_val=0
  sum_train=0
  i = 1
  for train_index, val_index in kf.split(x_training):
    print("Fold : ",i)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    clf.fit(X_train, y_train)
    y_val_pred = clf.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    sum_val += val_accuracy
    val_accuracy_list.append(val_accuracy)
    y_train_pred = clf.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    sum_train += train_accuracy
    train_accuracy_list.append(train_accuracy)
    i += 1 
  ave_val=sum_val/5
  ave_train=sum_train/5
  print("done")
  for i in range(0, len(train_accuracy_list)):
    print("train_accuracy : ", train_accuracy_list[i], "\tVal accuracy : ", val_accuracy_list[i])
  print("train_accuracy_ave : ",ave_train,"\tval accuracy_ave:",ave_val)
  print("Value of c",c)
# Out:
# Fold :  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-10e4e307ff59> in <module>()
#      18     sum_val += val_accuracy
#      19     val_accuracy_list.append(val_accuracy)
# ---> 20     y_train_pred = clf.predict(X_train)
#      21     train_accuracy = accuracy_score(y_train, y_train_pred)
#      22     sum_train += train_accuracy
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     592             y = np.argmax(self.decision_function(X), axis=1)
#     593         else:
# --> 594             y = super().predict(X)
#     595         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     596
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 317         return predict(X)
#     318
#     319     def _dense_predict(self, X):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in _dense_predict(self, X)
#     337             self.probA_, self.probB_, svm_type=svm_type, kernel=kernel,
#     338             degree=self.degree, coef0=self.coef0, gamma=self._gamma,
# --> 339             cache_size=self.cache_size)
#     340
#     341     def _sparse_predict(self, X):
#
# KeyboardInterrupt:
