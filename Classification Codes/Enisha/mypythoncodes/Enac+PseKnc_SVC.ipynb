# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import KFold

# %%
pos_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_pos_ENAC.npy"
neg_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_neg_ENAC.npy"
pos_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_pos_ENAC.npy"
neg_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_neg_ENAC.npy"


pos1_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_pos_PseKNC.npy"
neg1_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_neg_PseKNC.npy"
pos1_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_pos_pseknc.npy"
neg1_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_neg_pseknc.npy"




x_train_pos = np.concatenate((np.load(pos_5289),np.load(pos1_5289)),axis=1)
x_train_neg = np.concatenate((np.load(neg_5289),np.load(neg1_5289)),axis=1) 
x_test_pos = np.concatenate((np.load(pos_1000),np.load(pos1_1000)),axis=1)
x_test_neg = np.concatenate((np.load(neg_1000),np.load(neg1_1000)),axis=1)

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
print(x_train_pos.shape)
# Out:
# (5289, 214)

# %%
x_training=np.concatenate((x_train_pos,x_train_neg),axis=0)
y_training=np.concatenate((y_train_pos,y_train_neg))
x_test=np.concatenate((x_test_pos,x_test_neg))
y_test=np.concatenate((y_test_pos,y_test_neg))

# %%
print(x_training.shape)
# Out:
# (10578, 214)

# %%
seed = 40
np.random.seed(seed)

# %%
kf = KFold(n_splits=5, random_state=seed)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
listc=[.10,.20,.35,.40,.50,.60,.70,.80,.85,.95]
for j in listc:
  c=j
  clf = SVC(C=c,  random_state = seed)
  val_accuracy_list = []
  train_accuracy_list = []
  sum_val=0
  sum_train=0
  i = 1
  for train_index, val_index in kf.split(x_training):
    print("Fold : ",i)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    clf.fit(X_train, y_train)
    y_val_pred = clf.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)
    y_train_pred = clf.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)
    i += 1 
  print("done")
  for i in range(0, len(train_accuracy_list)):
    print("train_accuracy : ", train_accuracy_list[i], "\tVal accuracy : ", val_accuracy_list[i])
    sum_val+=val_accuracy_list[i]
    sum_train+=train_accuracy_list[i]
  ave_val=sum_val/5
  ave_train=sum_train/5
  print("train_accuracy_ave : ",ave_train,"\tval accuracy_ave:",ave_val)
  print("Value of c",c)
# Out:
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  0.9308674072323327 	Val accuracy :  0.2996219281663516
# train_accuracy :  0.841999527298511 	Val accuracy :  0.43241965973534974
# train_accuracy :  0.9035688962420232 	Val accuracy :  0.7802457466918714
# train_accuracy :  0.8931820867304738 	Val accuracy :  0.660047281323877
# train_accuracy :  0.8957816377171216 	Val accuracy :  0.5962174940898345
# train_accuracy_ave :  0.8930799110440925 	val accuracy_ave: 0.5537104220014568
# Value of c 0.1
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  0.9896005672417868 	Val accuracy :  0.3005671077504726
# train_accuracy :  0.9358307728669345 	Val accuracy :  0.5959357277882797
# train_accuracy :  0.9567478137556134 	Val accuracy :  0.8364839319470699
# train_accuracy :  0.9478908188585607 	Val accuracy :  0.8033096926713948
# train_accuracy :  0.9502540470282406 	Val accuracy :  0.7498817966903073
# train_accuracy_ave :  0.9560648039502272 	val accuracy_ave: 0.6572356513695049
# Value of c 0.2
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  0.9982273694162137 	Val accuracy :  0.2840264650283554
# train_accuracy :  0.9754195225714961 	Val accuracy :  0.6947069943289225
# train_accuracy :  0.9790829591113211 	Val accuracy :  0.8809073724007561
# train_accuracy :  0.978494623655914 	Val accuracy :  0.8955082742316784
# train_accuracy :  0.9774311709795581 	Val accuracy :  0.8288416075650118
# train_accuracy_ave :  0.9817311291469005 	val accuracy_ave: 0.7167981427109449
# Value of c 0.35
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  0.