# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import KFold

# %%
pos_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_pos_ENAC.npy"
neg_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_neg_ENAC.npy"
pos_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_pos_ENAC.npy"
neg_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_neg_ENAC.npy"


pos1_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_pos_PseKNC.npy"
neg1_5289 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana5289_neg_PseKNC.npy"
pos1_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_pos_pseknc.npy"
neg1_1000 = "/content/drive/My Drive/Pattern_Lab/npy/A.thaliana1000indep_neg_pseknc.npy"




x_train_pos = np.concatenate((np.load(pos_5289),np.load(pos1_5289)),axis=1)
x_train_neg = np.concatenate((np.load(neg_5289),np.load(neg1_5289)),axis=1) 
x_test_pos = np.concatenate((np.load(pos_1000),np.load(pos1_1000)),axis=1)
x_test_neg = np.concatenate((np.load(neg_1000),np.load(neg1_1000)),axis=1)

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
x_training=np.concatenate((x_train_pos,x_train_neg),axis=0)
y_training=np.concatenate((y_train_pos,y_train_neg))
x_test=np.concatenate((x_test_pos,x_test_neg))
y_test=np.concatenate((y_test_pos,y_test_neg))

# %%
seed = 40
np.random.seed(seed)

# %%
kf = KFold(n_splits=5, random_state=seed)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
listd=[1,10,20,30,40,50,60]
for j in listd:
  d=j
  clf = RandomForestClassifier(n_estimators=150, max_depth=d, random_state = seed)
  val_accuracy_list = []
  train_accuracy_list = []
  sum_val=0
  sum_train=0
  i = 1
  for train_index, val_index in kf.split(x_training):
    print("Fold : ",i)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    clf.fit(X_train, y_train)
    y_val_pred = clf.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)
    y_train_pred = clf.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)
    i += 1 
  print("done")
  for i in range(0, len(train_accuracy_list)):
    print("train_accuracy : ", train_accuracy_list[i], "\tVal accuracy : ", val_accuracy_list[i])
    sum_val+=val_accuracy_list[i]
    sum_train+=train_accuracy_list[i]
  ave_val=sum_val/5
  ave_train=sum_train/5
  print("train_accuracy_ave : ",ave_train,"\tval accuracy_ave:",ave_val)
  print("Value of d:",d)
# Out:
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  0.658827700307256 	Val accuracy :  0.008034026465028356
# train_accuracy :  0.6285748050106358 	Val accuracy :  0.0033081285444234404
# train_accuracy :  0.9216497281966438 	Val accuracy :  0.7599243856332704
# train_accuracy :  0.6273189176414983 	Val accuracy :  0.0028368794326241137
# train_accuracy :  0.6296821458111781 	Val accuracy :  0.0014184397163120568
# train_accuracy_ave :  0.6932106593934424 	val accuracy_ave: 0.15510437195833165
# Value of d: 1
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  0.9996454738832428 	Val accuracy :  0.1895085066162571
# train_accuracy :  0.9991727723942331 	Val accuracy :  0.9409262759924386
# train_accuracy :  0.998345544788466 	Val accuracy :  0.8804347826086957
# train_accuracy :  0.9979912560557722 	Val accuracy :  0.9390070921985816
# train_accuracy :  0.9974004490133522 	Val accuracy :  0.8023640661938535
# train_accuracy_ave :  0.9985110992270133 	val accuracy_ave: 0.7504481447219653
# Value of d: 10
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  1.0 	Val accuracy :  0.18525519848771266
# train_accuracy :  1.0 	Val accuracy :  0.943289224952741
# train_accuracy :  1.0 	Val accuracy :  0.8832703213610587
# train_accuracy :  1.0 	Val accuracy :  0.948936170212766
# train_accuracy :  1.0 	Val accuracy :  0.8316784869976359
# train_accuracy_ave :  1.0 	val accuracy_ave: 0.7584858804023827
# Value of d: 20
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  1.0 	Val accuracy :  0.18620037807183365
# train_accuracy :  1.0 	Val accuracy :  0.944234404536862
# train_accuracy :  1.0 	Val accuracy :  0.8865784499054821
# train_accuracy :  1.0 	Val accuracy :  0.9460992907801419
# train_accuracy :  1.0 	Val accuracy :  0.8349881796690307
# train_accuracy_ave :  1.0 	val accuracy_ave: 0.7596201405926701
# Value of d: 30
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  1.0 	Val accuracy :  0.18620037807183365
# train_accuracy :  1.0 	Val accuracy :  0.944234404536862
# train_accuracy :  1.0 	Val accuracy :  0.8865784499054821
# train_accuracy :  1.0 	Val accuracy :  0.9460992907801419
# train_accuracy :  1.0 	Val accuracy :  0.8349881796690307
# train_accuracy_ave :  1.0 	val accuracy_ave: 0.7596201405926701
# Value of d: 40
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  1.0 	Val accuracy :  0.18620037807183365
# train_accuracy :  1.0 	Val accuracy :  0.944234404536862
# train_accuracy :  1.0 	Val accuracy :  0.8865784499054821
# train_accuracy :  1.0 	Val accuracy :  0.9460992907801419
# train_accuracy :  1.0 	Val accuracy :  0.8349881796690307
# train_accuracy_ave :  1.0 	val accuracy_ave: 0.7596201405926701
# Value of d: 50
# Fold :  1
# Fold :  2
# Fold :  3
# Fold :  4
# Fold :  5
# done
# train_accuracy :  1.0 	Val accuracy :  0.18620037807183365
# train_accuracy :  1.0 	Val accuracy :  0.944234404536862
# train_accuracy :  1.0 	Val accuracy :  0.8865784499054821
# train_accuracy :  1.0 	Val accuracy :  0.9460992907801419
# train_accuracy :  1.0 	Val accuracy :  0.8349881796690307
# train_accuracy_ave :  1.0 	val accuracy_ave: 0.7596201405926701
# Value of d: 60
