# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/3wFuG-uAz591WV8AzBQOS4cKO6qt1ln0GKT6Mv9H6U9X4QYtqov7vv4
# Mounted at /content/drive

# %%
pos_5289 = "/content/drive/My Drive/pattern_fasta/A.thaliana5289_pos/kmer2/A.thaliana5289_pos_kmer_dnc_2.npy"
neg_5289 = "/content/drive/My Drive/pattern_fasta/A.thaliana5289_neg/kmer2/A.thaliana5289_neg_kmer_dnc.npy"
pos_1000 = "/content/drive/My Drive/pattern_fasta/A.thaliana1000indep_pos/kmer_dnc/A.thaliana1000indep_pos_kmer_dnc.npy"
neg_1000 = "/content/drive/My Drive/pattern_fasta/A.thaliana1000indep_neg/kmer_dnc/A.thaliana1000indep_neg_kmer_dnc.npy"

x_train_pos = np.load(pos_5289) 
x_train_neg = np.load(neg_5289) 
x_test_pos = np.load(pos_1000) 
x_test_neg = np.load(neg_1000) 

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
x_training = np.concatenate((x_train_pos, x_train_neg), axis = 0)
y_training = np.concatenate((y_train_pos, y_train_neg))

x_test = np.concatenate((x_test_pos, x_test_neg), axis = 0)
y_test = np.concatenate((y_test_pos, y_test_neg))

# %%
X_train, X_val, Y_train, Y_val = train_test_split(x_training, y_training, test_size=0.25, random_state=0)

# %%
seed = 100
np.random.seed(seed)

kf = KFold(n_splits=5, random_state=seed,shuffle=True)

# %%
test_avg_acc_list = []
j = 1
for c in range(50,502,50):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 50
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929111531190926 	Test Accuracy  0.678
# Train Accuracy :  1.0 	Validation Accuracy :  0.9891304347826086 	Test Accuracy  0.696
# Train Accuracy :  1.0 	Validation Accuracy :  0.9886578449905482 	Test Accuracy  0.704
# Train Accuracy :  1.0 	Validation Accuracy :  0.9867612293144208 	Test Accuracy  0.62
# Train Accuracy :  1.0 	Validation Accuracy :  0.9867612293144208 	Test Accuracy  0.7315
# Avg Test Accuracy: 0.6859000000000001
# Epoch 2/10 for C = 100
# Train Accuracy :  1.0 	Validation Accuracy :  0.9896030245746692 	Test Accuracy  0.667
# Train Accuracy :  1.0 	Validation Accuracy :  0.9896030245746692 	Test Accuracy  0.6485
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.598
# Train Accuracy :  1.0 	Validation Accuracy :  0.991016548463357 	Test Accuracy  0.654
# Train Accuracy :  1.0 	Validation Accuracy :  0.9881796690307328 	Test Accuracy  0.7395
# Avg Test Accuracy: 0.6614
# Epoch 3/10 for C = 150
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938563327032136 	Test Accuracy  0.6395
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905482041587902 	Test Accuracy  0.632
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.638
# Train Accuracy :  1.0 	Validation Accuracy :  0.9895981087470449 	Test Accuracy  0.655
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.6755
# Avg Test Accuracy: 0.6479999999999999
# Epoch 4/10 for C = 200
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933837429111532 	Test Accuracy  0.698
# Train Accuracy :  1.0 	Validation Accuracy :  0.9910207939508506 	Test Accuracy  0.676
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.681
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.637
# Train Accuracy :  1.0 	Validation Accuracy :  0.9891252955082742 	Test Accuracy  0.732
# Avg Test Accuracy: 0.6848000000000001
# Epoch 5/10 for C = 250
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933837429111532 	Test Accuracy  0.6755
# Train Accuracy :  1.0 	Validation Accuracy :  0.9910207939508506 	Test Accuracy  0.717
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.6835
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905437352245863 	Test Accuracy  0.6715
# Train Accuracy :  1.0 	Validation Accuracy :  0.9867612293144208 	Test Accuracy  0.667
# Avg Test Accuracy: 0.6829000000000001
# Epoch 6/10 for C = 300
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929111531190926 	Test Accuracy  0.699
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905482041587902 	Test Accuracy  0.7205
# Train Accuracy :  1.0 	Validation Accuracy :  0.9914933837429112 	Test Accuracy  0.6685
# Train Accuracy :  1.0 	Validation Accuracy :  0.991016548463357 	Test Accuracy  0.659
# Train Accuracy :  1.0 	Validation Accuracy :  0.9895981087470449 	Test Accuracy  0.705
# Avg Test Accuracy: 0.6904
# Epoch 7/10 for C = 350
# Train Accuracy :  1.0 	Validation Accuracy :  0.9919659735349716 	Test Accuracy  0.681
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.667
# Train Accuracy :  1.0 	Validation Accuracy :  0.9877126654064272 	Test Accuracy  0.6855
# Train Accuracy :  1.0 	Validation Accuracy :  0.991016548463357 	Test Accuracy  0.6795
# Train Accuracy :  1.0 	Validation Accuracy :  0.9895981087470449 	Test Accuracy  0.6825
# Avg Test Accuracy: 0.6791
# Epoch 8/10 for C = 400
# Train Accuracy :  1.0 	Validation Accuracy :  0.9914933837429112 	Test Accuracy  0.7035
# Train Accuracy :  1.0 	Validation Accuracy :  0.9896030245746692 	Test Accuracy  0.6685
# Train Accuracy :  1.0 	Validation Accuracy :  0.9910207939508506 	Test Accuracy  0.6605
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.6855
# Train Accuracy :  1.0 	Validation Accuracy :  0.991016548463357 	Test Accuracy  0.6995
# Avg Test Accuracy: 0.6835
# Epoch 9/10 for C = 450
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929111531190926 	Test Accuracy  0.6825
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905482041587902 	Test Accuracy  0.68
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905482041587902 	Test Accuracy  0.6355
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.6815
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905437352245863 	Test Accuracy  0.705
# Avg Test Accuracy: 0.6769000000000001
# Epoch 10/10 for C = 500
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933837429111532 	Test Accuracy  0.6885
# Train Accuracy :  1.0 	Validation Accuracy :  0.9919659735349716 	Test Accuracy  0.677
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.673
# Train Accuracy :  1.0 	Validation Accuracy :  0.9914893617021276 	Test Accuracy  0.674
# Train Accuracy :  1.0 	Validation Accuracy :  0.9891252955082742 	Test Accuracy  0.6815
# Avg Test Accuracy: 0.6788000000000001

# %%
test_avg_acc_list = []
j = 1
for c in range(300,350,10):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 300
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938563327032136 	Test Accuracy  0.6995
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.7015
# Train Accuracy :  1.0 	Validation Accuracy :  0.9896030245746692 	Test Accuracy  0.6385
# Train Accuracy :  1.0 	Validation Accuracy :  0.9895981087470449 	Test Accuracy  0.6895
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905437352245863 	Test Accuracy  0.6985
# Avg Test Accuracy: 0.6855
# Epoch 2/10 for C = 310
# Train Accuracy :  1.0 	Validation Accuracy :  0.9919659735349716 	Test Accuracy  0.6815
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.6995
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.648
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.682
# Train Accuracy :  1.0 	Validation Accuracy :  0.9891252955082742 	Test Accuracy  0.6885
# Avg Test Accuracy: 0.6799
# Epoch 3/10 for C = 320
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.6835
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.656
# Train Accuracy :  1.0 	Validation Accuracy :  0.9896030245746692 	Test Accuracy  0.7165
# Train Accuracy :  1.0 	Validation Accuracy :  0.9914893617021276 	Test Accuracy  0.695
# Train Accuracy :  1.0 	Validation Accuracy :  0.9886524822695035 	Test Accuracy  0.679
# Avg Test Accuracy: 0.6859999999999999
# Epoch 4/10 for C = 330
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933837429111532 	Test Accuracy  0.6585
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.697
# Train Accuracy :  1.0 	Validation Accuracy :  0.9896030245746692 	Test Accuracy  0.6845
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905437352245863 	Test Accuracy  0.6805
# Train Accuracy :  1.0 	Validation Accuracy :  0.9886524822695035 	Test Accuracy  0.6875
# Avg Test Accuracy: 0.6816
# Epoch 5/10 for C = 340
# Train Accuracy :  1.0 	Validation Accuracy :  0.9914933837429112 	Test Accuracy  0.6445
# Train Accuracy :  1.0 	Validation Accuracy :  0.9910207939508506 	Test Accuracy  0.7185
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.6475
# Train Accuracy :  1.0 	Validation Accuracy :  0.9914893617021276 	Test Accuracy  0.6825
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.7135
# Avg Test Accuracy: 0.6813

# %%
test_avg_acc_list = []
j = 1
for c in range(1,101,10):
  RFC = RandomForestClassifier(n_estimators=500,max_depth=c)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for depth = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for depth = 1
# Train Accuracy :  0.718388087922477 	Validation Accuracy :  0.7372400756143668 	Test Accuracy  0.684
# Train Accuracy :  0.7469865280075633 	Validation Accuracy :  0.7485822306238186 	Test Accuracy  0.6875
# Train Accuracy :  0.7078704797920113 	Validation Accuracy :  0.7069943289224953 	Test Accuracy  0.684
# Train Accuracy :  0.7185395249911379 	Validation Accuracy :  0.7144208037825059 	Test Accuracy  0.6815
# Train Accuracy :  0.7359092520382843 	Validation Accuracy :  0.7333333333333333 	Test Accuracy  0.6865
# Avg Test Accuracy: 0.6847000000000001
# Epoch 2/10 for depth = 11
# Train Accuracy :  0.9981091940439613 	Validation Accuracy :  0.9891304347826086 	Test Accuracy  0.691
# Train Accuracy :  0.9985818955329709 	Validation Accuracy :  0.9867674858223062 	Test Accuracy  0.717
# Train Accuracy :  0.9982273694162137 	Validation Accuracy :  0.9834593572778828 	Test Accuracy  0.664
# Train Accuracy :  0.9984639016897081 	Validation Accuracy :  0.9881796690307328 	Test Accuracy  0.691
# Train Accuracy :  0.9985820630981921 	Validation Accuracy :  0.9862884160756501 	Test Accuracy  0.725
# Avg Test Accuracy: 0.6976
# Epoch 3/10 for depth = 21
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929111531190926 	Test Accuracy  0.6805
# Train Accuracy :  1.0 	Validation Accuracy :  0.9919659735349716 	Test Accuracy  0.6895
# Train Accuracy :  1.0 	Validation Accuracy :  0.9891304347826086 	Test Accuracy  0.679
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905437352245863 	Test Accuracy  0.6925
# Train Accuracy :  1.0 	Validation Accuracy :  0.991016548463357 	Test Accuracy  0.7115
# Avg Test Accuracy: 0.6906000000000001
# Epoch 4/10 for depth = 31
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929111531190926 	Test Accuracy  0.6985
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.6805
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.6635
# Train Accuracy :  1.0 	Validation Accuracy :  0.991016548463357 	Test Accuracy  0.674
# Train Accuracy :  1.0 	Validation Accuracy :  0.9886524822695035 	Test Accuracy  0.706
# Avg Test Accuracy: 0.6845
# Epoch 5/10 for depth = 41
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933837429111532 	Test Accuracy  0.703
# Train Accuracy :  1.0 	Validation Accuracy :  0.9896030245746692 	Test Accuracy  0.7085
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905482041587902 	Test Accuracy  0.661
# Train Accuracy :  1.0 	Validation Accuracy :  0.9886524822695035 	Test Accuracy  0.6915
# Train Accuracy :  1.0 	Validation Accuracy :  0.9891252955082742 	Test Accuracy  0.6845
# Avg Test Accuracy: 0.6897
# Epoch 6/10 for depth = 51
# Train Accuracy :  1.0 	Validation Accuracy :  0.9919659735349716 	Test Accuracy  0.675
# Train Accuracy :  1.0 	Validation Accuracy :  0.9910207939508506 	Test Accuracy  0.704
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.6625
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.6915
# Train Accuracy :  1.0 	Validation Accuracy :  0.9895981087470449 	Test Accuracy  0.7215
# Avg Test Accuracy: 0.6909000000000001
# Epoch 7/10 for depth = 61
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.669
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.69
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.6535
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.6845
# Train Accuracy :  1.0 	Validation Accuracy :  0.9895981087470449 	Test Accuracy  0.71
# Avg Test Accuracy: 0.6814
# Epoch 8/10 for depth = 71
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.7095
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929111531190926 	Test Accuracy  0.7155
# Train Accuracy :  1.0 	Validation Accuracy :  0.9905482041587902 	Test Accuracy  0.662
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.671
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900709219858156 	Test Accuracy  0.6885
# Avg Test Accuracy: 0.6893
# Epoch 9/10 for depth = 81
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.694
# Train Accuracy :  1.0 	Validation Accuracy :  0.9896030245746692 	Test Accuracy  0.6605
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.661
# Train Accuracy :  1.0 	Validation Accuracy :  0.991016548463357 	Test Accuracy  0.6805
# Train Accuracy :  1.0 	Validation Accuracy :  0.9895981087470449 	Test Accuracy  0.681
# Avg Test Accuracy: 0.6754
# Epoch 10/10 for depth = 91
# Train Accuracy :  1.0 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.677
# Train Accuracy :  1.0 	Validation Accuracy :  0.9900756143667296 	Test Accuracy  0.6695
# Train Accuracy :  1.0 	Validation Accuracy :  0.9886578449905482 	Test Accuracy  0.68
# Train Accuracy :  1.0 	Validation Accuracy :  0.9914893617021276 	Test Accuracy  0.674
# Train Accuracy :  1.0 	Validation Accuracy :  0.9886524822695035 	Test Accuracy  0.6815
# Avg Test Accuracy: 0.6763999999999999
