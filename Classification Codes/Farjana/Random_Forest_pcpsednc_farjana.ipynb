# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/3wHSVOug-Sagz3W1WkkSMOWZNbXFqZOCu-4igZCIRUZ6MvalmFtdNew
# Mounted at /content/drive

# %%
pos_5289 = "/content/drive/My Drive/pattern_fasta/A.thaliana5289_pos/pcpsednc/A.thaliana5289_pos_pspsednc.npy"
neg_5289 = "/content/drive/My Drive/pattern_fasta/A.thaliana5289_neg/pcpsednc/A.thaliana5289_neg_pcpsednc.npy"
pos_1000 = "/content/drive/My Drive/pattern_fasta/A.thaliana1000indep_pos/pcpsednc/A.thaliana1000indep_pos_pcpsednc.npy"
neg_1000 = "/content/drive/My Drive/pattern_fasta/A.thaliana1000indep_neg/pcpsednc/A.thaliana1000indep_neg_pcpsednc.npy"

x_train_pos = np.load(pos_5289) 
x_train_neg = np.load(neg_5289) 
x_test_pos = np.load(pos_1000) 
x_test_neg = np.load(neg_1000) 

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
x_training = np.concatenate((x_train_pos, x_train_neg), axis = 0)
y_training = np.concatenate((y_train_pos, y_train_neg))

x_test = np.concatenate((x_test_pos, x_test_neg), axis = 0)
y_test = np.concatenate((y_test_pos, y_test_neg))

# %%
X_train, X_val, Y_train, Y_val = train_test_split(x_training, y_training, test_size=0.25, random_state=0)

# %%
seed = 100
np.random.seed(seed)

kf = KFold(n_splits=5, random_state=seed,shuffle=True)

# %%
test_avg_acc_list = []
j = 1
for c in range(50,502,50):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 50
# Train Accuracy :  1.0 	Validation Accuracy :  0.9324196597353497 	Test Accuracy  0.758
# Train Accuracy :  1.0 	Validation Accuracy :  0.9319470699432892 	Test Accuracy  0.7735
# Train Accuracy :  1.0 	Validation Accuracy :  0.9262759924385633 	Test Accuracy  0.773
# Train Accuracy :  1.0 	Validation Accuracy :  0.9286052009456265 	Test Accuracy  0.744
# Train Accuracy :  1.0 	Validation Accuracy :  0.9210401891252955 	Test Accuracy  0.771
# Avg Test Accuracy: 0.7781
# Epoch 8/10 for C = 400
# Train Accuracy :  1.0 	Validation Accuracy :  0.943289224952741 	Test Accuracy  0.7805
# Train Accuracy :  1.0 	Validation Accuracy :  0.9333648393194707 	Test Accuracy  0.779
# Train Accuracy :  1.0 	Validation Accuracy :  0.9262759924385633 	Test Accuracy  0.78
# Train Accuracy :  1.0 	Validation Accuracy :  0.9356973995271868 	Test Accuracy  0.7645
# Train Accuracy :  1.0 	Validation Accuracy :  0.9276595744680851 	Test Accuracy  0.7725
# Avg Test Accuracy: 0.7753
# Epoch 9/10 for C = 450
# Train Accuracy :  1.0 	Validation Accuracy :  0.941398865784499 	Test Accuracy  0.777
# Train Accuracy :  1.0 	Validation Accuracy :  0.9328922495274102 	Test Accuracy  0.783
# Train Accuracy :  1.0 	Validation Accuracy :  0.9234404536862004 	Test Accuracy  0.781
# Train Accuracy :  1.0 	Validation Accuracy :  0.9328605200945627 	Test Accuracy  0.7705
# Train Accuracy :  1.0 	Validation Accuracy :  0.9257683215130024 	Test Accuracy  0.7845
# Avg Test Accuracy: 0.7792000000000001
# Epoch 10/10 for C = 500
# Train Accuracy :  1.0 	Validation Accuracy :  0.943289224952741 	Test Accuracy  0.777
# Train Accuracy :  1.0 	Validation Accuracy :  0.9343100189035917 	Test Accuracy  0.7805
# Train Accuracy :  1.0 	Validation Accuracy :  0.9272211720226843 	Test Accuracy  0.781
# Train Accuracy :  1.0 	Validation Accuracy :  0.9352245862884161 	Test Accuracy  0.7695
# Train Accuracy :  1.0 	Validation Accuracy :  0.9281323877068558 	Test Accuracy  0.7895
# Avg Test Accuracy: 0.7795

# %%
test_avg_acc_list = []
j = 1
for c in range(200,252,10):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 200
# Train Accuracy :  1.0 	Validation Accuracy :  0.94234404536862 	Test Accuracy  0.7715
# Train Accuracy :  1.0 	Validation Accuracy :  0.9319470699432892 	Test Accuracy  0.7735
# Train Accuracy :  1.0 	Validation Accuracy :  0.9281663516068053 	Test Accuracy  0.7855
# Train Accuracy :  1.0 	Validation Accuracy :  0.9375886524822695 	Test Accuracy  0.7825
# Train Accuracy :  1.0 	Validation Accuracy :  0.926241134751773 	Test Accuracy  0.785
# Avg Test Accuracy: 0.7796
# Epoch 2/10 for C = 210
# Train Accuracy :  1.0 	Validation Accuracy :  0.9409262759924386 	Test Accuracy  0.7785
# Train Accuracy :  1.0 	Validation Accuracy :  0.9343100189035917 	Test Accuracy  0.7765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9258034026465028 	Test Accuracy  0.779
# Train Accuracy :  1.0 	Validation Accuracy :  0.9356973995271868 	Test Accuracy  0.7645
# Train Accuracy :  1.0 	Validation Accuracy :  0.9252955082742317 	Test Accuracy  0.7815
# Avg Test Accuracy: 0.776
# Epoch 3/10 for C = 220
# Train Accuracy :  1.0 	Validation Accuracy :  0.9447069943289225 	Test Accuracy  0.7775
# Train Accuracy :  1.0 	Validation Accuracy :  0.9291115311909263 	Test Accuracy  0.772
# Train Accuracy :  1.0 	Validation Accuracy :  0.9253308128544423 	Test Accuracy  0.7775
# Train Accuracy :  1.0 	Validation Accuracy :  0.9319148936170213 	Test Accuracy  0.778
# Train Accuracy :  1.0 	Validation Accuracy :  0.9286052009456265 	Test Accuracy  0.7785
# Avg Test Accuracy: 0.7767
# Epoch 4/10 for C = 230
# Train Accuracy :  1.0 	Validation Accuracy :  0.944234404536862 	Test Accuracy  0.7895
# Train Accuracy :  1.0 	Validation Accuracy :  0.9324196597353497 	Test Accuracy  0.779
# Train Accuracy :  1.0 	Validation Accuracy :  0.9276937618147448 	Test Accuracy  0.779
# Train Accuracy :  1.0 	Validation Accuracy :  0.9342789598108747 	Test Accuracy  0.7745
# Train Accuracy :  1.0 	Validation Accuracy :  0.9290780141843972 	Test Accuracy  0.783
# Avg Test Accuracy: 0.7809999999999999
# Epoch 5/10 for C = 240
# Train Accuracy :  1.0 	Validation Accuracy :  0.941398865784499 	Test Accuracy  0.772
# Train Accuracy :  1.0 	Validation Accuracy :  0.9376181474480151 	Test Accuracy  0.7865
# Train Accuracy :  1.0 	Validation Accuracy :  0.9286389413988658 	Test Accuracy  0.777
# Train Accuracy :  1.0 	Validation Accuracy :  0.9352245862884161 	Test Accuracy  0.7765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9267139479905437 	Test Accuracy  0.783
# Avg Test Accuracy: 0.779
# Epoch 6/10 for C = 250
# Train Accuracy :  1.0 	Validation Accuracy :  0.9399810964083176 	Test Accuracy  0.7785
# Train Accuracy :  1.0 	Validation Accuracy :  0.9399810964083176 	Test Accuracy  0.778
# Train Accuracy :  1.0 	Validation Accuracy :  0.9258034026465028 	Test Accuracy  0.7815
# Train Accuracy :  1.0 	Validation Accuracy :  0.9328605200945627 	Test Accuracy  0.758
# Train Accuracy :  1.0 	Validation Accuracy :  0.9257683215130024 	Test Accuracy  0.786
# Avg Test Accuracy: 0.7764

# %%
test_avg_acc_list = []
j = 1
for c in range(230,240,1):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 230
# Train Accuracy :  1.0 	Validation Accuracy :  0.941398865784499 	Test Accuracy  0.77
# Train Accuracy :  1.0 	Validation Accuracy :  0.9333648393194707 	Test Accuracy  0.787
# Train Accuracy :  1.0 	Validation Accuracy :  0.9239130434782609 	Test Accuracy  0.7795
# Train Accuracy :  1.0 	Validation Accuracy :  0.9342789598108747 	Test Accuracy  0.771
# Train Accuracy :  1.0 	Validation Accuracy :  0.9286052009456265 	Test Accuracy  0.778
# Avg Test Accuracy: 0.7771
# Epoch 2/10 for C = 231
# Train Accuracy :  1.0 	Validation Accuracy :  0.944234404536862 	Test Accuracy  0.779
# Train Accuracy :  1.0 	Validation Accuracy :  0.9333648393194707 	Test Accuracy  0.782
# Train Accuracy :  1.0 	Validation Accuracy :  0.9267485822306238 	Test Accuracy  0.772
# Train Accuracy :  1.0 	Validation Accuracy :  0.9404255319148936 	Test Accuracy  0.7765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9281323877068558 	Test Accuracy  0.7815
# Avg Test Accuracy: 0.7782
# Epoch 3/10 for C = 232
# Train Accuracy :  1.0 	Validation Accuracy :  0.943289224952741 	Test Accuracy  0.7775
# Train Accuracy :  1.0 	Validation Accuracy :  0.9305293005671077 	Test Accuracy  0.783
# Train Accuracy :  1.0 	Validation Accuracy :  0.9258034026465028 	Test Accuracy  0.7755
# Train Accuracy :  1.0 	Validation Accuracy :  0.9385342789598109 	Test Accuracy  0.7735
# Train Accuracy :  1.0 	Validation Accuracy :  0.9252955082742317 	Test Accuracy  0.776
# Avg Test Accuracy: 0.7770999999999999
# Epoch 4/10 for C = 233
# Train Accuracy :  1.0 	Validation Accuracy :  0.9428166351606805 	Test Accuracy  0.7685
# Train Accuracy :  1.0 	Validation Accuracy :  0.9343100189035917 	Test Accuracy  0.783
# Train Accuracy :  1.0 	Validation Accuracy :  0.9300567107750473 	Test Accuracy  0.7765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9319148936170213 	Test Accuracy  0.7695
# Train Accuracy :  1.0 	Validation Accuracy :  0.9252955082742317 	Test Accuracy  0.778
# Avg Test Accuracy: 0.7750999999999999
# Epoch 5/10 for C = 234
# Train Accuracy :  1.0 	Validation Accuracy :  0.94234404536862 	Test Accuracy  0.7765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9333648393194707 	Test Accuracy  0.7855
# Train Accuracy :  1.0 	Validation Accuracy :  0.9248582230623819 	Test Accuracy  0.783
# Train Accuracy :  1.0 	Validation Accuracy :  0.9342789598108747 	Test Accuracy  0.778
# Train Accuracy :  1.0 	Validation Accuracy :  0.9281323877068558 	Test Accuracy  0.7785
# Avg Test Accuracy: 0.7802999999999999
# Epoch 6/10 for C = 235
# Train Accuracy :  1.0 	Validation Accuracy :  0.945179584120983 	Test Accuracy  0.7825
# Train Accuracy :  1.0 	Validation Accuracy :  0.9328922495274102 	Test Accuracy  0.7855
# Train Accuracy :  1.0 	Validation Accuracy :  0.9253308128544423 	Test Accuracy  0.779
# Train Accuracy :  1.0 	Validation Accuracy :  0.9356973995271868 	Test Accuracy  0.7705
# Train Accuracy :  1.0 	Validation Accuracy :  0.9252955082742317 	Test Accuracy  0.7905
# Avg Test Accuracy: 0.7815999999999999
# Epoch 7/10 for C = 236
# Train Accuracy :  1.0 	Validation Accuracy :  0.9418714555765595 	Test Accuracy  0.7785
# Train Accuracy :  1.0 	Validation Accuracy :  0.9319470699432892 	Test Accuracy  0.775
# Train Accuracy :  1.0 	Validation Accuracy :  0.9229678638941399 	Test Accuracy  0.7815
# Train Accuracy :  1.0 	Validation Accuracy :  0.932387706855792 	Test Accuracy  0.772
# Train Accuracy :  1.0 	Validation Accuracy :  0.9300236406619385 	Test Accuracy  0.79
# Avg Test Accuracy: 0.7794000000000001
# Epoch 8/10 for C = 237
# Train Accuracy :  1.0 	Validation Accuracy :  0.9409262759924386 	Test Accuracy  0.7815
# Train Accuracy :  1.0 	Validation Accuracy :  0.9338374291115312 	Test Accuracy  0.7825
# Train Accuracy :  1.0 	Validation Accuracy :  0.9295841209829868 	Test Accuracy  0.775
# Train Accuracy :  1.0 	Validation Accuracy :  0.9390070921985816 	Test Accuracy  0.7705
# Train Accuracy :  1.0 	Validation Accuracy :  0.9257683215130024 	Test Accuracy  0.785
# Avg Test Accuracy: 0.7788999999999999
# Epoch 9/10 for C = 238
# Train Accuracy :  1.0 	Validation Accuracy :  0.941398865784499 	Test Accuracy  0.7795
# Train Accuracy :  1.0 	Validation Accuracy :  0.9324196597353497 	Test Accuracy  0.786
# Train Accuracy :  1.0 	Validation Accuracy :  0.9234404536862004 	Test Accuracy  0.781
# Train Accuracy :  1.0 	Validation Accuracy :  0.9304964539007092 	Test Accuracy  0.766
# Train Accuracy :  1.0 	Validation Accuracy :  0.9276595744680851 	Test Accuracy  0.7825
# Avg Test Accuracy: 0.7790000000000001
# Epoch 10/10 for C = 239
# Train Accuracy :  1.0 	Validation Accuracy :  0.945179584120983 	Test Accuracy  0.7795
# Train Accuracy :  1.0 	Validation Accuracy :  0.9328922495274102 	Test Accuracy  0.7915
# Train Accuracy :  1.0 	Validation Accuracy :  0.9272211720226843 	Test Accuracy  0.7715
# Train Accuracy :  1.0 	Validation Accuracy :  0.9333333333333333 	Test Accuracy  0.762
# Train Accuracy :  1.0 	Validation Accuracy :  0.9243498817966903 	Test Accuracy  0.7845
# Avg Test Accuracy: 0.7777999999999999

# %%
test_avg_acc_list = []
j = 1
for c in range(1,101,10):
  RFC = RandomForestClassifier(n_estimators=200,max_depth=c)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for depth = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for depth = 1
# Train Accuracy :  0.7996927440321437 	Validation Accuracy :  0.7986767485822306 	Test Accuracy  0.567
# Train Accuracy :  0.8189553297092886 	Validation Accuracy :  0.8171077504725898 	Test Accuracy  0.6705
# Train Accuracy :  0.7878752068069015 	Validation Accuracy :  0.776937618147448 	Test Accuracy  0.5235
# Train Accuracy :  0.8094056481153256 	Validation Accuracy :  0.8141843971631205 	Test Accuracy  0.6615
# Train Accuracy :  0.7903816613494032 	Validation Accuracy :  0.7848699763593381 	Test Accuracy  0.545
# Avg Test Accuracy: 0.5934999999999999
# Epoch 2/10 for depth = 11
# Train Accuracy :  0.9883006381470102 	Validation Accuracy :  0.9343100189035917 	Test Accuracy  0.7715
# Train Accuracy :  0.9874734105412432 	Validation Accuracy :  0.9243856332703214 	Test Accuracy  0.7775
# Train Accuracy :  0.9858189553297093 	Validation Accuracy :  0.916351606805293 	Test Accuracy  0.7705
# Train Accuracy :  0.9888928276025051 	Validation Accuracy :  0.9281323877068558 	Test Accuracy  0.764
# Train Accuracy :  0.9881838591516011 	Validation Accuracy :  0.9210401891252955 	Test Accuracy  0.7815
# Avg Test Accuracy: 0.7729999999999999
# Epoch 3/10 for depth = 21
# Train Accuracy :  1.0 	Validation Accuracy :  0.9395085066162571 	Test Accuracy  0.777
# Train Accuracy :  1.0 	Validation Accuracy :  0.9324196597353497 	Test Accuracy  0.7775
# Train Accuracy :  1.0 	Validation Accuracy :  0.9276937618147448 	Test Accuracy  0.7745
# Train Accuracy :  1.0 	Validation Accuracy :  0.9371158392434988 	Test Accuracy  0.7595
# Train Accuracy :  1.0 	Validation Accuracy :  0.9276595744680851 	Test Accuracy  0.7775
# Avg Test Accuracy: 0.7731999999999999
# Epoch 4/10 for depth = 31
# Train Accuracy :  1.0 	Validation Accuracy :  0.943289224952741 	Test Accuracy  0.7745
# Train Accuracy :  1.0 	Validation Accuracy :  0.9366729678638941 	Test Accuracy  0.7835
# Train Accuracy :  1.0 	Validation Accuracy :  0.9234404536862004 	Test Accuracy  0.7745
# Train Accuracy :  1.0 	Validation Accuracy :  0.9333333333333333 	Test Accuracy  0.77
# Train Accuracy :  1.0 	Validation Accuracy :  0.924822695035461 	Test Accuracy  0.7825
# Avg Test Accuracy: 0.7769999999999999
