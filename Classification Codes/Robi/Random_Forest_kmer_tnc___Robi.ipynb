# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
pos_5289 = "/content/drive/My Drive/Fasta RNA feature vectors/A.thaliana5289_pos/kmer3/A.thaliana5289_pos_kmer_tnc_3.npy"
neg_5289 = "/content/drive/My Drive/Fasta RNA feature vectors/A.thaliana5289_neg/kmer3/A.thaliana5289_neg_kmer_tnc.npy"
pos_1000 = "/content/drive/My Drive/Fasta RNA feature vectors/A.thaliana1000indep_pos/kmer3/A.thaliana1000indep_pos_kmer_tnc.npy"
neg_1000 = "/content/drive/My Drive/Fasta RNA feature vectors/A.thaliana1000indep_neg/kmer_tnc/A.thaliana1000indep_neg_kmer_tnc.npy"

x_train_pos = np.load(pos_5289) 
x_train_neg = np.load(neg_5289) 
x_test_pos = np.load(pos_1000) 
x_test_neg = np.load(neg_1000) 

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
x_training = np.concatenate((x_train_pos, x_train_neg), axis = 0)
y_training = np.concatenate((y_train_pos, y_train_neg))

x_test = np.concatenate((x_test_pos, x_test_neg), axis = 0)
y_test = np.concatenate((y_test_pos, y_test_neg))

# %%
X_train, X_val, Y_train, Y_val = train_test_split(x_training, y_training, test_size=0.25, random_state=0)

# %%
seed = 100
np.random.seed(seed)

kf = KFold(n_splits=5, random_state=seed,shuffle=True)

# %%
test_avg_acc_list = []
j = 1
for c in range(50,502,50):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 50
# Train Accuracy :  1.0 	Validation Accuracy :  0.9948015122873346 	Test Accuracy  0.856
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938563327032136 	Test Accuracy  0.804
# Train Accuracy :  1.0 	Validation Accuracy :  0.9948015122873346 	Test Accuracy  0.867
# Train Accuracy :  1.0 	Validation Accuracy :  0.9947990543735225 	Test Accuracy  0.8615
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966903073286052 	Test Accuracy  0.8545
# Avg Test Accuracy: 0.8486
# Epoch 2/10 for C = 100
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.8545
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.839
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.863
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938534278959811 	Test Accuracy  0.854
# Train Accuracy :  1.0 	Validation Accuracy :  0.9962174940898345 	Test Accuracy  0.8325
# Avg Test Accuracy: 0.8486
# Epoch 3/10 for C = 150
# Train Accuracy :  1.0 	Validation Accuracy :  0.9948015122873346 	Test Accuracy  0.8295
# Train Accuracy :  1.0 	Validation Accuracy :  0.994328922495274 	Test Accuracy  0.8565
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966918714555766 	Test Accuracy  0.886
# Train Accuracy :  1.0 	Validation Accuracy :  0.9952718676122931 	Test Accuracy  0.8645
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976359338061466 	Test Accuracy  0.8565
# Avg Test Accuracy: 0.8586
# Epoch 4/10 for C = 200
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.846
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933837429111532 	Test Accuracy  0.86
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.877
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938534278959811 	Test Accuracy  0.846
# Train Accuracy :  1.0 	Validation Accuracy :  0.9981087470449173 	Test Accuracy  0.8435
# Avg Test Accuracy: 0.8545
# Epoch 5/10 for C = 250
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966918714555766 	Test Accuracy  0.862
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.8645
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976370510396976 	Test Accuracy  0.842
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938534278959811 	Test Accuracy  0.851
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966903073286052 	Test Accuracy  0.871
# Avg Test Accuracy: 0.8581
# Epoch 6/10 for C = 300
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966918714555766 	Test Accuracy  0.856
# Train Accuracy :  1.0 	Validation Accuracy :  0.9948015122873346 	Test Accuracy  0.846
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976370510396976 	Test Accuracy  0.857
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929078014184397 	Test Accuracy  0.8495
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8525
# Avg Test Accuracy: 0.8522000000000001
# Epoch 7/10 for C = 350
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.8465
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.855
# Train Accuracy :  1.0 	Validation Accuracy :  0.998109640831758 	Test Accuracy  0.85
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938534278959811 	Test Accuracy  0.8605
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8545
# Avg Test Accuracy: 0.8533
# Epoch 8/10 for C = 400
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.832
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.868
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976370510396976 	Test Accuracy  0.8535
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.8455
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976359338061466 	Test Accuracy  0.859
# Avg Test Accuracy: 0.8516
# Epoch 9/10 for C = 450
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.861
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.862
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966918714555766 	Test Accuracy  0.8625
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938534278959811 	Test Accuracy  0.859
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.869
# Avg Test Accuracy: 0.8626999999999999
# Epoch 10/10 for C = 500
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.8505
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.865
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976370510396976 	Test Accuracy  0.866
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938534278959811 	Test Accuracy  0.8585
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966903073286052 	Test Accuracy  0.8665
# Avg Test Accuracy: 0.8613000000000002

# %%
test_avg_acc_list = []
j = 1
for c in range(450,502,10):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 450
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.8645
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.86
# Train Accuracy :  1.0 	Validation Accuracy :  0.998109640831758 	Test Accuracy  0.853
# Train Accuracy :  1.0 	Validation Accuracy :  0.9943262411347518 	Test Accuracy  0.846
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976359338061466 	Test Accuracy  0.8475
# Avg Test Accuracy: 0.8542
# Epoch 2/10 for C = 460
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966918714555766 	Test Accuracy  0.8705
# Train Accuracy :  1.0 	Validation Accuracy :  0.9948015122873346 	Test Accuracy  0.8715
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976370510396976 	Test Accuracy  0.864
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.8535
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8515
# Avg Test Accuracy: 0.8622
# Epoch 3/10 for C = 470
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.8545
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.867
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976370510396976 	Test Accuracy  0.863
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.864
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8755
# Avg Test Accuracy: 0.8648
# Epoch 4/10 for C = 480
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.8555
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.8535
# Train Accuracy :  1.0 	Validation Accuracy :  0.997164461247637 	Test Accuracy  0.845
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938534278959811 	Test Accuracy  0.8455
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8605
# Avg Test Accuracy: 0.852
# Epoch 5/10 for C = 490
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.862
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966918714555766 	Test Accuracy  0.849
# Train Accuracy :  1.0 	Validation Accuracy :  0.998109640831758 	Test Accuracy  0.8675
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938534278959811 	Test Accuracy  0.8525
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976359338061466 	Test Accuracy  0.8705
# Avg Test Accuracy: 0.8603
# Epoch 6/10 for C = 500
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.851
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.865
# Train Accuracy :  1.0 	Validation Accuracy :  0.9985822306238186 	Test Accuracy  0.8595
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.855
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966903073286052 	Test Accuracy  0.8715
# Avg Test Accuracy: 0.8603999999999999

# %%
test_avg_acc_list = []
j = 1
for c in range(1,101,10):
  RFC = RandomForestClassifier(n_estimators=500,max_depth=c)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for depth = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for depth = 1
# Train Accuracy :  0.8814701016308202 	Validation Accuracy :  0.8851606805293005 	Test Accuracy  0.7315
# Train Accuracy :  0.8769794374852281 	Validation Accuracy :  0.8686200378071833 	Test Accuracy  0.7335
# Train Accuracy :  0.8728432994563933 	Validation Accuracy :  0.8794896030245747 	Test Accuracy  0.7155
# Train Accuracy :  0.8830202056008508 	Validation Accuracy :  0.8780141843971632 	Test Accuracy  0.717
# Train Accuracy :  0.8847926267281107 	Validation Accuracy :  0.8822695035460993 	Test Accuracy  0.7185
# Avg Test Accuracy: 0.7232000000000001
# Epoch 2/10 for depth = 11
# Train Accuracy :  0.9984637201607185 	Validation Accuracy :  0.9924385633270322 	Test Accuracy  0.8555
# Train Accuracy :  0.9979910186717088 	Validation Accuracy :  0.9929111531190926 	Test Accuracy  0.8635
# Train Accuracy :  0.9982273694162137 	Validation Accuracy :  0.9948015122873346 	Test Accuracy  0.863
# Train Accuracy :  0.9982275788727402 	Validation Accuracy :  0.992434988179669 	Test Accuracy  0.8475
# Train Accuracy :  0.9977549332388042 	Validation Accuracy :  0.9952718676122931 	Test Accuracy  0.868
# Avg Test Accuracy: 0.8595
# Epoch 3/10 for depth = 21
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.848
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938563327032136 	Test Accuracy  0.8525
# Train Accuracy :  1.0 	Validation Accuracy :  0.998109640831758 	Test Accuracy  0.8605
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929078014184397 	Test Accuracy  0.8455
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8585
# Avg Test Accuracy: 0.853
# Epoch 4/10 for depth = 31
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966918714555766 	Test Accuracy  0.8565
# Train Accuracy :  1.0 	Validation Accuracy :  0.9948015122873346 	Test Accuracy  0.8785
# Train Accuracy :  1.0 	Validation Accuracy :  0.997164461247637 	Test Accuracy  0.8465
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.8595
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.851
# Avg Test Accuracy: 0.8583999999999999
# Epoch 5/10 for depth = 41
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.859
# Train Accuracy :  1.0 	Validation Accuracy :  0.9938563327032136 	Test Accuracy  0.8575
# Train Accuracy :  1.0 	Validation Accuracy :  0.998109640831758 	Test Accuracy  0.8515
# Train Accuracy :  1.0 	Validation Accuracy :  0.9929078014184397 	Test Accuracy  0.858
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966903073286052 	Test Accuracy  0.861
# Avg Test Accuracy: 0.8573999999999999
# Epoch 6/10 for depth = 51
# Train Accuracy :  1.0 	Validation Accuracy :  0.9966918714555766 	Test Accuracy  0.857
# Train Accuracy :  1.0 	Validation Accuracy :  0.996219281663516 	Test Accuracy  0.857
# Train Accuracy :  1.0 	Validation Accuracy :  0.9985822306238186 	Test Accuracy  0.8595
# Train Accuracy :  1.0 	Validation Accuracy :  0.9947990543735225 	Test Accuracy  0.8535
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8525
# Avg Test Accuracy: 0.8559000000000001
# Epoch 7/10 for depth = 61
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.8465
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.871
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976370510396976 	Test Accuracy  0.8465
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.8505
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8665
# Avg Test Accuracy: 0.8562000000000001
# Epoch 8/10 for depth = 71
# Train Accuracy :  1.0 	Validation Accuracy :  0.995274102079395 	Test Accuracy  0.8555
# Train Accuracy :  1.0 	Validation Accuracy :  0.9948015122873346 	Test Accuracy  0.8655
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976370510396976 	Test Accuracy  0.8635
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.8635
# Train Accuracy :  1.0 	Validation Accuracy :  0.9976359338061466 	Test Accuracy  0.8645
# Avg Test Accuracy: 0.8625
# Epoch 9/10 for depth = 81
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.851
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.8545
# Train Accuracy :  1.0 	Validation Accuracy :  0.997164461247637 	Test Accuracy  0.857
# Train Accuracy :  1.0 	Validation Accuracy :  0.9933806146572104 	Test Accuracy  0.8575
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8525
# Avg Test Accuracy: 0.8545
# Epoch 10/10 for depth = 91
# Train Accuracy :  1.0 	Validation Accuracy :  0.9957466918714556 	Test Accuracy  0.8515
# Train Accuracy :  1.0 	Validation Accuracy :  0.994328922495274 	Test Accuracy  0.851
# Train Accuracy :  1.0 	Validation Accuracy :  0.997164461247637 	Test Accuracy  0.8525
# Train Accuracy :  1.0 	Validation Accuracy :  0.9947990543735225 	Test Accuracy  0.8505
# Train Accuracy :  1.0 	Validation Accuracy :  0.9971631205673759 	Test Accuracy  0.8595
# Avg Test Accuracy: 0.853
