# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
pos_5289 = "/content/drive/My Drive/Fasta RNA feature vectors/A.thaliana5289_pos/pseknc/A.thaliana5289_pos_pseknc.npy"
neg_5289 = "/content/drive/My Drive/Fasta RNA feature vectors/A.thaliana5289_neg/pseknc/A.thaliana5289_neg_pseknc.npy"
pos_1000 = "/content/drive/My Drive/Fasta RNA feature vectors/A.thaliana1000indep_pos/pseknc/A.thaliana1000indep_pos_pseknc.npy"
neg_1000 = "/content/drive/My Drive/Fasta RNA feature vectors/A.thaliana1000indep_neg/pseknc/A.thaliana1000indep_neg_pseknc.npy"

x_train_pos = np.load(pos_5289) 
x_train_neg = np.load(neg_5289) 
x_test_pos = np.load(pos_1000) 
x_test_neg = np.load(neg_1000) 

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
x_training = np.concatenate((x_train_pos, x_train_neg), axis = 0)
y_training = np.concatenate((y_train_pos, y_train_neg))

x_test = np.concatenate((x_test_pos, x_test_neg), axis = 0)
y_test = np.concatenate((y_test_pos, y_test_neg))

# %%
X_train, X_val, Y_train, Y_val = train_test_split(x_training, y_training, test_size=0.25, random_state=0)

# %%
seed = 100
np.random.seed(seed)

kf = KFold(n_splits=5, random_state=seed,shuffle=True)

# %%
test_avg_acc_list = []
j = 1
for c in range(50,502,50):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 50
# Train Accuracy :  1.0 	Validation Accuracy :  0.968336483931947 	Test Accuracy  0.7405
# Train Accuracy :  1.0 	Validation Accuracy :  0.9688090737240076 	Test Accuracy  0.763
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725897920604915 	Test Accuracy  0.744
# Train Accuracy :  1.0 	Validation Accuracy :  0.9773049645390071 	Test Accuracy  0.7575
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725768321513002 	Test Accuracy  0.7505
# Avg Test Accuracy: 0.7510999999999999
# Epoch 2/10 for C = 100
# Train Accuracy :  1.0 	Validation Accuracy :  0.974952741020794 	Test Accuracy  0.7545
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.776
# Train Accuracy :  1.0 	Validation Accuracy :  0.9768431001890359 	Test Accuracy  0.7695
# Train Accuracy :  1.0 	Validation Accuracy :  0.9796690307328605 	Test Accuracy  0.7605
# Train Accuracy :  1.0 	Validation Accuracy :  0.9749408983451536 	Test Accuracy  0.7655
# Avg Test Accuracy: 0.7651999999999999
# Epoch 9/10 for C = 450
# Train Accuracy :  1.0 	Validation Accuracy :  0.9782608695652174 	Test Accuracy  0.76
# Train Accuracy :  1.0 	Validation Accuracy :  0.974952741020794 	Test Accuracy  0.775
# Train Accuracy :  1.0 	Validation Accuracy :  0.9782608695652174 	Test Accuracy  0.7655
# Train Accuracy :  1.0 	Validation Accuracy :  0.9801418439716312 	Test Accuracy  0.7655
# Train Accuracy :  1.0 	Validation Accuracy :  0.975886524822695 	Test Accuracy  0.7675
# Avg Test Accuracy: 0.7666999999999999
# Epoch 10/10 for C = 500
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744801512287334 	Test Accuracy  0.754
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744801512287334 	Test Accuracy  0.7665
# Train Accuracy :  1.0 	Validation Accuracy :  0.974952741020794 	Test Accuracy  0.7595
# Train Accuracy :  1.0 	Validation Accuracy :  0.9801418439716312 	Test Accuracy  0.759
# Train Accuracy :  1.0 	Validation Accuracy :  0.9739952718676123 	Test Accuracy  0.7695
# Avg Test Accuracy: 0.7616999999999999

# %%
test_avg_acc_list = []
j = 1
for c in range(200,252,10):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 200
# Train Accuracy :  1.0 	Validation Accuracy :  0.9773156899810964 	Test Accuracy  0.7615
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716446124763705 	Test Accuracy  0.757
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.772
# Train Accuracy :  1.0 	Validation Accuracy :  0.9791962174940898 	Test Accuracy  0.7585
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735224586288416 	Test Accuracy  0.7705
# Avg Test Accuracy: 0.7638999999999999
# Epoch 2/10 for C = 210
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725897920604915 	Test Accuracy  0.7515
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.7695
# Train Accuracy :  1.0 	Validation Accuracy :  0.9777882797731569 	Test Accuracy  0.7635
# Train Accuracy :  1.0 	Validation Accuracy :  0.9796690307328605 	Test Accuracy  0.758
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706855791962175 	Test Accuracy  0.765
# Avg Test Accuracy: 0.7615000000000001
# Epoch 3/10 for C = 220
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.7595
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725897920604915 	Test Accuracy  0.7725
# Train Accuracy :  1.0 	Validation Accuracy :  0.9777882797731569 	Test Accuracy  0.765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9801418439716312 	Test Accuracy  0.757
# Train Accuracy :  1.0 	Validation Accuracy :  0.9749408983451536 	Test Accuracy  0.76
# Avg Test Accuracy: 0.7628
# Epoch 4/10 for C = 230
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.7545
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.7595
# Train Accuracy :  1.0 	Validation Accuracy :  0.9763705103969754 	Test Accuracy  0.765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9796690307328605 	Test Accuracy  0.769
# Train Accuracy :  1.0 	Validation Accuracy :  0.9730496453900709 	Test Accuracy  0.7685
# Avg Test Accuracy: 0.7633
# Epoch 5/10 for C = 240
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.753
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.772
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744801512287334 	Test Accuracy  0.7515
# Train Accuracy :  1.0 	Validation Accuracy :  0.9796690307328605 	Test Accuracy  0.7475
# Train Accuracy :  1.0 	Validation Accuracy :  0.9754137115839243 	Test Accuracy  0.7665
# Avg Test Accuracy: 0.7581
# Epoch 6/10 for C = 250
# Train Accuracy :  1.0 	Validation Accuracy :  0.974952741020794 	Test Accuracy  0.7435
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744801512287334 	Test Accuracy  0.764
# Train Accuracy :  1.0 	Validation Accuracy :  0.9777882797731569 	Test Accuracy  0.7695
# Train Accuracy :  1.0 	Validation Accuracy :  0.9806146572104019 	Test Accuracy  0.763
# Train Accuracy :  1.0 	Validation Accuracy :  0.975886524822695 	Test Accuracy  0.769
# Avg Test Accuracy: 0.7618

# %%
test_avg_acc_list = []
j = 1
for c in range(200,210,1):
  RFC = RandomForestClassifier(n_estimators=c,max_depth=None)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for C = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for C = 200
# Train Accuracy :  1.0 	Validation Accuracy :  0.9754253308128544 	Test Accuracy  0.755
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.7715
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.744
# Train Accuracy :  1.0 	Validation Accuracy :  0.9796690307328605 	Test Accuracy  0.7575
# Train Accuracy :  1.0 	Validation Accuracy :  0.9702127659574468 	Test Accuracy  0.7575
# Avg Test Accuracy: 0.7571
# Epoch 2/10 for C = 201
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744801512287334 	Test Accuracy  0.7665
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.7795
# Train Accuracy :  1.0 	Validation Accuracy :  0.9754253308128544 	Test Accuracy  0.7705
# Train Accuracy :  1.0 	Validation Accuracy :  0.9801418439716312 	Test Accuracy  0.7525
# Train Accuracy :  1.0 	Validation Accuracy :  0.9721040189125295 	Test Accuracy  0.766
# Avg Test Accuracy: 0.7669999999999999
# Epoch 3/10 for C = 202
# Train Accuracy :  1.0 	Validation Accuracy :  0.9787334593572778 	Test Accuracy  0.7615
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.7715
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744801512287334 	Test Accuracy  0.748
# Train Accuracy :  1.0 	Validation Accuracy :  0.9763593380614657 	Test Accuracy  0.7505
# Train Accuracy :  1.0 	Validation Accuracy :  0.9730496453900709 	Test Accuracy  0.7625
# Avg Test Accuracy: 0.7587999999999999
# Epoch 4/10 for C = 203
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.7615
# Train Accuracy :  1.0 	Validation Accuracy :  0.9763705103969754 	Test Accuracy  0.7655
# Train Accuracy :  1.0 	Validation Accuracy :  0.9768431001890359 	Test Accuracy  0.767
# Train Accuracy :  1.0 	Validation Accuracy :  0.9810874704491725 	Test Accuracy  0.755
# Train Accuracy :  1.0 	Validation Accuracy :  0.9721040189125295 	Test Accuracy  0.7765
# Avg Test Accuracy: 0.7651
# Epoch 5/10 for C = 204
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.745
# Train Accuracy :  1.0 	Validation Accuracy :  0.9754253308128544 	Test Accuracy  0.772
# Train Accuracy :  1.0 	Validation Accuracy :  0.9754253308128544 	Test Accuracy  0.762
# Train Accuracy :  1.0 	Validation Accuracy :  0.9801418439716312 	Test Accuracy  0.752
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735224586288416 	Test Accuracy  0.7645
# Avg Test Accuracy: 0.7590999999999999
# Epoch 6/10 for C = 205
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.7545
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706994328922496 	Test Accuracy  0.7765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9768431001890359 	Test Accuracy  0.762
# Train Accuracy :  1.0 	Validation Accuracy :  0.9806146572104019 	Test Accuracy  0.7725
# Train Accuracy :  1.0 	Validation Accuracy :  0.9716312056737588 	Test Accuracy  0.76
# Avg Test Accuracy: 0.7651
# Epoch 7/10 for C = 206
# Train Accuracy :  1.0 	Validation Accuracy :  0.9773156899810964 	Test Accuracy  0.7615
# Train Accuracy :  1.0 	Validation Accuracy :  0.975897920604915 	Test Accuracy  0.763
# Train Accuracy :  1.0 	Validation Accuracy :  0.975897920604915 	Test Accuracy  0.752
# Train Accuracy :  1.0 	Validation Accuracy :  0.9796690307328605 	Test Accuracy  0.75
# Train Accuracy :  1.0 	Validation Accuracy :  0.9744680851063829 	Test Accuracy  0.766
# Avg Test Accuracy: 0.7585
# Epoch 8/10 for C = 207
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.75
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.7615
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.7605
# Train Accuracy :  1.0 	Validation Accuracy :  0.9791962174940898 	Test Accuracy  0.7475
# Train Accuracy :  1.0 	Validation Accuracy :  0.9749408983451536 	Test Accuracy  0.774
# Avg Test Accuracy: 0.7586999999999999
# Epoch 9/10 for C = 208
# Train Accuracy :  1.0 	Validation Accuracy :  0.975897920604915 	Test Accuracy  0.76
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.781
# Train Accuracy :  1.0 	Validation Accuracy :  0.9754253308128544 	Test Accuracy  0.768
# Train Accuracy :  1.0 	Validation Accuracy :  0.9801418439716312 	Test Accuracy  0.7525
# Train Accuracy :  1.0 	Validation Accuracy :  0.9692671394799054 	Test Accuracy  0.7615
# Avg Test Accuracy: 0.7646
# Epoch 10/10 for C = 209
# Train Accuracy :  1.0 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.755
# Train Accuracy :  1.0 	Validation Accuracy :  0.974952741020794 	Test Accuracy  0.7765
# Train Accuracy :  1.0 	Validation Accuracy :  0.9763705103969754 	Test Accuracy  0.7585
# Train Accuracy :  1.0 	Validation Accuracy :  0.9777777777777777 	Test Accuracy  0.7565
# Train Accuracy :  1.0 	Validation Accuracy :  0.9735224586288416 	Test Accuracy  0.7675
# Avg Test Accuracy: 0.7628

# %%
test_avg_acc_list = []
j = 1
for c in range(1,101,10):
  RFC = RandomForestClassifier(n_estimators=200,max_depth=c)
  val_accuracy_list = []
  train_accuracy_list = []
  test_acc_list = []
  test_avg = 0
  for train_index, val_index in kf.split(x_training):
    #print("train = ",train_index,"Val =",val_index)
    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    RFC.fit(X_train, y_train)

    y_val_pred = RFC.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = RFC.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    y_test_pred = RFC.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_acc_list.append(test_accuracy)
    test_avg = test_avg + test_accuracy
  test_avg = test_avg/5
  print(f"Epoch {j}/{10} for depth = {c}")
  j=j+1
  for i in range(0, len(train_accuracy_list)):
    print("Train Accuracy : ", train_accuracy_list[i], "\tValidation Accuracy : ", val_accuracy_list[i],"\tTest Accuracy ",test_acc_list[i])
  print("Avg Test Accuracy:",test_avg)
# Out:
# Epoch 1/10 for depth = 1
# Train Accuracy :  0.8967147246513827 	Validation Accuracy :  0.8913043478260869 	Test Accuracy  0.699
# Train Accuracy :  0.8930512881115575 	Validation Accuracy :  0.8719281663516069 	Test Accuracy  0.7275
# Train Accuracy :  0.8912786575277712 	Validation Accuracy :  0.8851606805293005 	Test Accuracy  0.6785
# Train Accuracy :  0.8933002481389578 	Validation Accuracy :  0.9106382978723404 	Test Accuracy  0.6675
# Train Accuracy :  0.8901098901098901 	Validation Accuracy :  0.8817966903073287 	Test Accuracy  0.6215
# Avg Test Accuracy: 0.6788000000000001
# Epoch 2/10 for depth = 11
# Train Accuracy :  0.9979910186717088 	Validation Accuracy :  0.9706994328922496 	Test Accuracy  0.769
# Train Accuracy :  0.998345544788466 	Validation Accuracy :  0.9735349716446124 	Test Accuracy  0.782
# Train Accuracy :  0.998345544788466 	Validation Accuracy :  0.973062381852552 	Test Accuracy  0.765
# Train Accuracy :  0.9981094174642562 	Validation Accuracy :  0.9768321513002364 	Test Accuracy  0.7615
# Train Accuracy :  0.9982275788727402 	Validation Accuracy :  0.9692671394799054 	Test Accuracy  0.767
# Avg Test Accuracy: 0.7689
# Epoch 3/10 for depth = 21
# Train Accuracy :  1.0 	Validation Accuracy :  0.972117202268431 	Test Accuracy  0.758
# Train Accuracy :  1.0 	Validation Accuracy :  0.9706994328922496 	Test Accuracy  0.77
# Train Accuracy :  1.0 	Validation Accuracy :  0.974007561436673 	Test Accuracy  0.7585
# Train Accuracy :  1.0 	Validation Accuracy :  0.9787234042553191 	Test Accuracy  0.7635
# Train Accuracy :  1.0 	Validation Accuracy :  0.9754137115839243 	Test Accuracy  0.762
# Avg Test Accuracy: 0.7624000000000001
# Epoch 4/10 for depth = 31
# Train Accuracy :  1.0 	Validation Accuracy :  0.9773156899810964 	Test Accuracy  0.7575
# Train Accuracy :  1.0 	Validation Accuracy :  0.9725897920604915 	Test Accuracy  0.767
# Train Accuracy :  1.0 	Validation Accuracy :  0.975897920604915 	Test Accuracy  0.76
# Train Accuracy :  1.0 	Validation Accuracy :  0.9796690307328605 	Test Accuracy  0.754
# Train Accuracy :  1.0 	Validation Accuracy :  0.9721040189125295 	Test Accuracy  0.7605
# Avg Test Accuracy: 0.7598
# Epoch 5/10 for depth = 41
